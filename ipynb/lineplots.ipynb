# %% [markdown]
# [Sebastian Raschka](http://www.sebastianraschka.com)

# %%
# %load_ext watermark

# %%
# %watermark
# Out:
# 05/07/2014 01:56:46
#
# CPython 3.4.1
# IPython 2.1.0
#
# compiler   : GCC 4.2.1 (Apple Inc. build 5577)
# system     : Darwin
# release    : 13.2.0
# machine    : x86_64
# processor  : i386
# CPU cores  : 2
# interpreter: 64bit

# %% [markdown]
# <font size="2em">[More info](http://nbviewer.ipython.org/github/rasbt/python_reference/blob/master/ipython_magic/watermark.ipynb) about the `%watermark` extension</font>

# %%
# %matplotlib inline

# %% [markdown]
# <br>
# <br>

# %% [markdown]
# # Sections

# %% [markdown]
# - [Simple line plot](#Simple-line-plot)
#
# - [Line plot with error bars](#Line-plot-with-error-bars)
#
# - [Line plot with x-axis labels and log-scale](#Line-plot-with-x-axis-labels-and-log-scale)
#
# - [Gaussian probability density functions](#Gaussian-probability-density-functions)
#
# - [Cumulative Plots](#Cumulative-Plots)

# %% [markdown]
# <br>
# <br>

# %% [markdown]
# # Simple line plot

# %% [markdown]
# [[back to top](#Sections)]

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3]

y_1 = [50, 60, 70]
y_2 = [20, 30, 40]

plt.plot(x, y_1, marker='x')
plt.plot(x, y_2, marker='^')

plt.xlim([0, len(x)+1])
plt.ylim([0, max(y_1+y_2) + 10])
plt.xlabel('x-axis label')
plt.ylabel('y-axis label')
plt.title('Simple line plot')
plt.legend(['sample 1', 'sample2'], loc='upper left')

plt.show()

# %% [markdown]
# <br>
# <br>

# %% [markdown]
# # Line plot with error bars

# %% [markdown]
# [[back to top](#Sections)]

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3]

y_1 = [50, 60, 70]
y_2 = [20, 30, 40]

y_1_err = [4.3, 4.5, 2.0] 
y_2_err = [2.3, 6.9, 2.1] 

x_labels = ["x1", "x2", "x3"]

plt.errorbar(x, y_1, yerr=y_1_err, fmt='-x')
plt.errorbar(x, y_2, yerr=y_2_err, fmt='-^')

plt.xticks(x, x_labels)
plt.xlim([0, len(x)+1])
plt.ylim([0, max(y_1+y_2) + 10])
plt.xlabel('x-axis label')
plt.ylabel('y-axis label')
plt.title('Line plot with error bars')
plt.legend(['sample 1', 'sample2'], loc='upper left')

plt.show()

# %% [markdown]
# <br>
# <br>

# %% [markdown]
# # Line plot with x-axis labels and log-scale

# %% [markdown]
# [[back to top](#Sections)]

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3]

y_1 = [0.5,7.0,60.0]
y_2 = [0.3,6.0,30.0]



x_labels = ["x1", "x2", "x3"]

plt.plot(x, y_1, marker='x')
plt.plot(x, y_2, marker='^')

plt.xticks(x, x_labels)
plt.xlim([0,4])
plt.xlabel('x-axis label')
plt.ylabel('y-axis label')
plt.yscale('log')
plt.title('Line plot with x-axis labels and log-scale')
plt.legend(['sample 1', 'sample2'], loc='upper left')

plt.show()

# %% [markdown]
# <br>
# <br>

# %% [markdown]
# # Gaussian probability density functions

# %% [markdown]
# [[back to top](#Sections)]

# %%
import numpy as np
from matplotlib import pyplot as plt
import math

def pdf(x, mu=0, sigma=1):
    """
    Calculates the normal distribution's probability density 
    function (PDF).  
        
    """
    term1 = 1.0 / ( math.sqrt(2*np.pi) * sigma )
    term2 = np.exp( -0.5 * ( (x-mu)/sigma )**2 )
    return term1 * term2


x = np.arange(0, 100, 0.05)

pdf1 = pdf(x, mu=5, sigma=2.5**0.5)
pdf2 = pdf(x, mu=10, sigma=6**0.5)

plt.plot(x, pdf1)
plt.plot(x, pdf2)
plt.title('Probability Density Functions')
plt.ylabel('p(x)')
plt.xlabel('random variable x')
plt.legend(['pdf1 ~ N(5,2.5)', 'pdf2 ~ N(10,6)'], loc='upper right')
plt.ylim([0,0.5])
plt.xlim([0,20])

plt.show()

# %% [markdown]
# <br>
# <br>

# %% [markdown]
# # Cumulative Plots

# %% [markdown]
# [[back to top](#Sections)]

# %%
import numpy as np
import matplotlib.pyplot as plt

A = np.arange(1, 11)
B = np.random.randn(10) # 10 rand. values from a std. norm. distr.
plt.step(A, B.cumsum(), label='cumulative sum') # cumulative sum via numpy.cumsum()
plt.scatter(A, B, label='actual values')

plt.ylabel('value')
plt.xlabel('sample number')
plt.title('Cumulative sum of 10 samples from a random normal distribution')
plt.legend(loc='upper right')

plt.show()
